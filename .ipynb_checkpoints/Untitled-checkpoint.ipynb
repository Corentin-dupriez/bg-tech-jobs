# %%
import kagglehub
import pandas as pd

# %%
path = kagglehub.dataset_download("dimodimchev/bulgarias-it-job-market")

# %%
print(path)
# Out:
# /Users/corentindupriez/.cache/kagglehub/datasets/dimodimchev/bulgarias-it-job-market/versions/1

# %%
df = pd.read_csv(path + '/cleaned_dataset.csv')

# %%
df
# Out:
#      id        date  backenddevelopment  java  dotnet  php  ccplusplusembeded  \
# 0     1  2023-08-13                 953   284     183  130                138
# 1     2  2023-08-14                 954   282     187  128                139
# 2    14  2023-08-15                 951   284     187  125                136
# 3    25  2023-08-16                 955   282     188  126                137
# 4    31  2023-08-17                 939   273     184  129                133
# ..  ...         ...                 ...   ...     ...  ...                ...
# 75  177  2023-10-27                 838   239     166  104                129
# 76  179  2023-10-28                 836   239     166  104                129
# 77  181  2023-10-29                 836   239     166  104                129
# 78  183  2023-10-30                 840   242     160  102                133
# 79  189  2023-10-31                 837   240     161  104                134
#
# ...

# %%
df['date'] = pd.to_datetime(df['date'])

# %%
df.loc[:,'backenddevelopment':'junior':1].groupby(df['date'].dt.to_period('M')).mean().info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# PeriodIndex: 3 entries, 2023-08 to 2023-10
# Freq: M
# Data columns (total 32 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   backenddevelopment   3 non-null      float64
#  1   java                 3 non-null      float64
#  2   dotnet               3 non-null      float64
#  3   php                  3 non-null      float64
#  4   ccplusplusembeded    3 non-null      float64
#  5   python               3 non-null      float64
#  6   ruby                 3 non-null      float64
#  7   go                   3 non-null      float64
#  8   nodejs               3 non-null      float64
#  9   frontenddevelopment  3 non-null      float64
#  10  js                   3 non-null      float64
#  11  react                3 non-null      float64
#  12  angular              3 non-null      float64
#  13  vue                  3 non-null      float64
# ...
