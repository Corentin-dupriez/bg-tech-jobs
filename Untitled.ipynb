# %% [markdown]
# # 💼 IT Job Listings in Bulgaria (2023–2025)
#
# This notebook analyzes trends in Bulgaria's IT job market by comparing historical data from 2023 with newly scraped data from [Dev.bg](https://dev.bg). The goal is to identify how the number and distribution of job listings have evolved between 2023 and 2025.
#
# The analysis builds upon a 2023 dataset available on [Kaggle](https://www.kaggle.com/code/dimodimchev/deep-dive-into-bulgaria-s-it-job-market-trends/input), and extends it using a custom web scraper and a data updating module that collects and integrates recent job listings into the same CSV file.

# %% [markdown]
# ## 🛠️ Data Pipeline Overview
#
# The data was collected using a custom web scraper built with `BeautifulSoup`, and cleaned using a Python utility module.
#
# - Source: [dev.bg](https://dev.bg)
# - Fields collected: date, number of listings for back-end development, java, .NET, PHP, C/C++/Embedded, Python, Ruby, Go, Node.js, front-end development, JavaScript, React, Angular, Vue, Full-stack development, PM/BA, QA, DevOps, DB engineer, Cyber security, Sys admin, data warehouse, big data, data visualization, ML and AI, UI/UX, technical support, mobile, iOS, Android, IT management, junior
# - Output: `data/cleaned_dataset.csv`
#
# 📌 You can regenerate the dataset by running `python main.py`.

# %%
import pandas as pd
import os
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.set_theme()

# %%
file = os.path.join(os.getcwd(), 'data' , 'cleaned_dataset.csv')

# %%
df = pd.read_csv(file)

# %%
df['date'] = pd.to_datetime(df['date'])

# %%
df.head()
# Out:
#    id       date  backenddevelopment  java  dotnet  php  ccplusplusembeded  \
# 0   1 2023-08-13                 953   284     183  130                138
# 1   2 2023-08-14                 954   282     187  128                139
# 2  14 2023-08-15                 951   284     187  125                136
# 3  25 2023-08-16                 955   282     188  126                137
# 4  31 2023-08-17                 939   273     184  129                133
#
#    python  ruby  go  ...  bigdata  datavisualisation  mlandai  ui_ux  \
# 0      85     7  21  ...       15                 55       45     52
# 1      86     8  22  ...       15                 56       46     51
# 2      82     8  24  ...       16                 55       47     54
# 3      83     8  23  ...       16                 55       45     54
# 4      83     7  23  ...       16                 55       46     55
#
#    technical_support  mobile  ios  android  itmanagment  junior
# 0                123      86   28       40           27     146
# 1                121      86   28       40           26     144
# 2                116      86   28       40           25     150
# 3                116      83   28       39           26     138
# 4                112      90   29       44           27     131
#
# [5 rows x 34 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 82 entries, 0 to 81
# Data columns (total 34 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   id                   82 non-null     int64
#  1   date                 82 non-null     datetime64[ns]
#  2   backenddevelopment   82 non-null     int64
#  3   java                 82 non-null     int64
#  4   dotnet               82 non-null     int64
#  5   php                  82 non-null     int64
#  6   ccplusplusembeded    82 non-null     int64
#  7   python               82 non-null     int64
#  8   ruby                 82 non-null     int64
#  9   go                   82 non-null     int64
#  10  nodejs               82 non-null     int64
#  11  frontenddevelopment  82 non-null     int64
#  12  js                   82 non-null     int64
#  13  react                82 non-null     int64
#  14  angular              82 non-null     int64
#  15  vue                  82 non-null     int64
#  16  fulstackdevelopment  82 non-null     int64
#  17  pmandba              82 non-null     int64
#  18  qa                   82 non-null     int64
#  19  devops               82 non-null     int64
#  20  databaseengineer     82 non-null     int64
#  21  cybersecurity        82 non-null     int64
#  22  sysadmin             82 non-null     int64
#  23  datawarehouse        82 non-null     int64
#  24  bigdata              82 non-null     int64
#  25  datavisualisation    82 non-null     int64
#  26  mlandai              82 non-null     int64
#  27  ui_ux                82 non-null     int64
#  28  technical_support    82 non-null     int64
#  29  mobile               82 non-null     int64
#  30  ios                  82 non-null     int64
#  31  android              82 non-null     int64
#  32  itmanagment          82 non-null     int64
#  33  junior               82 non-null     int64
# dtypes: datetime64[ns](1), int64(33)
# memory usage: 21.9 KB

# %%
(df[['backenddevelopment', 'frontenddevelopment', 'fulstackdevelopment', 'mobile']]
 .groupby(df['date'].dt.to_period('M'))
 .mean()
 .round(2))
# Out:
#          backenddevelopment  frontenddevelopment  fulstackdevelopment  mobile
# date
# 2023-08              925.63               426.26               221.00   88.26
# 2023-09              853.93               400.03               197.90   86.13
# 2023-10              852.03               394.81               195.52   84.10
# 2025-06              620.00               239.00               144.50   46.00

# %%
technologies = (df[['backenddevelopment', 'frontenddevelopment', 'fulstackdevelopment', 'mobile']]
 .groupby(df['date'].dt.to_period('M'))
 .mean()
 .round(2))

# %%
plt.figure(figsize=(10,6))
technologies.T[technologies.T.columns[::-1]].plot(kind='barh')
plt.xlabel('Number of listings')
plt.ylabel('Dev technology')
plt.title('Evolution of the number of job listings by technology over time')
# Out:
# Text(0.5, 1.0, 'Evolution of the number of job listings by technology over time')

# %% [markdown]
# It looks like there is a constant diminution in the search for developers in Bulgaria.

# %%
plt.figure(figsize=(10,6))
(df[['date', 'java', 'dotnet', 'php', 'ccplusplusembeded', 'python', 'ruby', 'go', 'nodejs']]
 .set_index('date')
 .loc['2023-10-31']
 .plot(kind='pie', autopct='%.0f%%', labels=['Java', '.NET', 'PHP', 'C/C++/Embedded', 'Python', 'Ruby', 'Go', 'Node.js']))
# Out:
# <Axes: ylabel='2023-10-31 00:00:00'>

# %% [markdown]
# In 2023, Java and .NET were the first two technologies with the most listings. It was followed by PHP and C/C++.

# %%
plt.figure(figsize=(10,6))
(df[['date', 'java', 'dotnet', 'php', 'ccplusplusembeded', 'python', 'ruby', 'go', 'nodejs']]
 .set_index('date')
 .loc['2025-06-02']
 .plot(kind='pie', autopct='%.0f%%', labels=['Java', '.NET', 'PHP', 'C/C++/Embedded', 'Python', 'Ruby', 'Go', 'Node.js']))
# Out:
# <Axes: ylabel='2025-06-02 00:00:00'>

# %% [markdown]
# In 2025, the same 2 technologies are at the top, but Python has jumped to the 3rd place.

# %%
(df[['date', 'python']][df['date'].astype('str').isin(['2023-08-13', '2025-06-03'])]
 .plot(kind='bar',
       x='date',
       y='python',
       rot=0,
       xlabel='Date',))
# Out:
# <Axes: xlabel='Date'>
